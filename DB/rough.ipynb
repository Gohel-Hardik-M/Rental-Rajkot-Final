# %% [markdown]
# <url>
#     <loc>https://rental-rajkot-final.onrender.com/contact</loc>
# </url>
#
# <url>
#     <loc>https://rental-rajkot-final.onrender.com/privacy</loc>
# </url>
#
# <url>
#     <loc>https://rental-rajkot-final.onrender.com/terms</loc>
# </url>
#
# <url>
#     <loc>https://rental-rajkot-final.onrender.com/faq</loc>
# </url>
